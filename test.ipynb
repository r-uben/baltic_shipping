# %%
import pandas as pd

# %%
import pandas as pd
import os
import glob
import json
from tqdm import tqdm

# Find all JSON files in data/ directory and subdirectories
all_json_files = glob.glob("data/**/*.json", recursive=True)
print(f"Found {len(all_json_files)} JSON files")

# Read and combine all JSON files into a single DataFrame
data_list = []
for json_file in tqdm(all_json_files, desc="Processing JSON files", unit="file"):
    try:
        with open(json_file, 'r', encoding='utf-8') as f:
            data = json.load(f)
            # If data is a dictionary, convert to list
            if isinstance(data, dict):
                data_list.append(data)
            elif isinstance(data, list):
                data_list.extend(data)
    except Exception as e:
        print(f"Error reading {json_file}: {e}")

# Convert to DataFrame and save as CSV
if data_list:
    print("Converting to DataFrame and saving...")
    df = pd.DataFrame(data_list)
    output_file = "data/combined_vessels.csv"
    df.to_csv(output_file, index=False)
    print(f"Combined {len(data_list)} records into {output_file}")
    print(f"DataFrame shape: {df.shape}")
else:
    print("No data found to combine")
# Out:
# Found 71041 JSON files
# Processing JSON files: 100%|██████████| 71041/71041 [22:24<00:00, 52.85file/s]
# Converting to DataFrame and saving...
# Combined 71041 records into data/combined_vessels.csv
# DataFrame shape: (71041, 23)

# %%
df
# Out:
#       IMO number           Vessel type        Operating status         Flag  \
# 0        5388134        Fishing vessel  Decommissioned or lost       Canada
# 1        6855304              Tug boat  Decommissioned or lost          NaN
# 2        7329534    Lash/Barge carrier  Decommissioned or lost        India
# 3        8925218  General cargo vessel                  Active        Japan
# 4        9104902        Container ship  Decommissioned or lost        Palau
# ...          ...                   ...                     ...          ...
# 71036    9451240          Bulk carrier                  Active      Bahamas
# 71037    5163819   Chemical/Oil tanker  Decommissioned or lost      Bahamas
# 71038    7205192          Bulk carrier  Decommissioned or lost  North Korea
# 71039    7202657        Fishing vessel  Decommissioned or lost          NaN
# 71040    9119098          Bulk carrier  Decommissioned or lost  Philippines
#
#       Year of build                                            Builder  \
# 0              1943        QUINCY ADAMS YACHT YARD - QUINCY MA, U.S.A.
# 1              1936                                                NaN
# 2              1974                   DANYARD - FREDERIKSHAVN, DENMARK
# 3              1996                 YANO SHIPBUILDING - IMABARI, JAPAN
# 4              1995  HYUNDAI HEAVY INDUSTRIES CO. LTD. - ULSAN, SOU...
# ...             ...                                                ...
# 71036          2011            STX DALIAN SHIPBUILDING - DALIAN, CHINA
# 71037          1944  CONSOLIDATED WESTERN STEEL SAN PEDRO - SAN PED...
# 71038          1972          SHIN YAMAMOTO SHIPBUILDING - KOCHI, JAPAN
# 71039          1914                  KING & WINGE - SEATTLE WA, U.S.A.
# 71040          1995  SANOYAS MIZUSHIMA WORKS & SHIPYARD - KURASHIKI...
#
#                                              Description         Vessel name  \
# 0      WESTERN DISPATCHER is a Fishing vessel built i...  WESTERN DISPATCHER
# 1      KIM is a Tug boat built in 1936. Current statu...                 KIM
# 2      BACAT I is a Lash/Barge carrier built in 1974 ...             BACAT I
# 3      SUNNY KISSHO is a General cargo vessel built i...        SUNNY KISSHO
# 4      OEL EMIRATES is a Container ship built in 1995...        OEL EMIRATES
# ...                                                  ...                 ...
# 71036  SERENE JESSICA is a Bulk carrier built in 2011...      SERENE JESSICA
# 71037  IRVING HICKORY is a Chemical/Oil tanker built ...      IRVING HICKORY
# 71038  JODIE is a Bulk carrier built in 1972 by SHIN ...               JODIE
# 71039  KING & WINGE is a Fishing vessel built in 1914...        KING & WINGE
# 71040  WORLD SWAN is a Bulk carrier built in 1995 by ...          WORLD SWAN
#
#       Gross tonnage (tons)                                         source_url  \
# 0                  133tons  https://www.balticshipping.com/vessel/imo/5388134
# 1                  376tons  https://www.balticshipping.com/vessel/imo/6855304
# 2                 1339tons  https://www.balticshipping.com/vessel/imo/7329534
# 3                  199tons  https://www.balticshipping.com/vessel/imo/8925218
# 4                36606tons  https://www.balticshipping.com/vessel/imo/9104902
# ...                    ...                                                ...
# 71036            33226tons  https://www.balticshipping.com/vessel/imo/9451240
# 71037              614tons  https://www.balticshipping.com/vessel/imo/5163819
# 71038            10478tons  https://www.balticshipping.com/vessel/imo/7205192
# 71039              143tons  https://www.balticshipping.com/vessel/imo/7202657
# 71040            39023tons  https://www.balticshipping.com/vessel/imo/9119098
#
#        ... Deadweight (tons)       MMSI  \
# 0      ...               NaN        NaN
# 1      ...               NaN        NaN
# 2      ...          1840tons        NaN
# 3      ...           699tons        NaN
# 4      ...         45240tons  511966000
# ...    ...               ...        ...
# 71036  ...         57275tons  311047600
# 71037  ...          1006tons        NaN
# 71038  ...         16999tons        NaN
# 71039  ...               NaN        NaN
# 71040  ...         46799tons  548223000
#
#                                             Former names Home port  \
# 0                                                    NaN       NaN
# 1                                                    NaN       NaN
# 2                                                    NaN       NaN
# 3                                                    NaN       NaN
# 4      OEL EMIRATES(2019, Panama)NORFOLK EXPRESS(2015...  HAMILTON
# ...                                                  ...       ...
# 71036                              MARIA V.LIVANOS(2013)    NASSAU
# 71037                                MELENGER(1962)YW 93       NaN
# 71038  EUROBULKER VII(2003)JODIE D(1997)CHIOS DESTINY...       NaN
# 71039                                     COLUMBIA(1914)       NaN
# 71040                                                NaN       NaN
#
#                                              Owner  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                   HAPAG LLOYD - HAMBURG, GERMANY
# ...                                            ...
# 71036               TROJAN MARITIME ATHENS, GREECE
# 71037                                          NaN
# 71038                                          NaN
# 71039                                          NaN
# 71040  MULTINATIONAL MARITIME MANILA - PHILIPPINES
#
#                                                Manager Engine type  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4      ANGLO EASTERN SHIPMANAGEMENT - HONG KONG, CHINA         NaN
# ...                                                ...         ...
# 71036                   TROJAN MARITIME ATHENS, GREECE     MAN-B&W
# 71037                                              NaN         NaN
# 71038                                              NaN         NaN
# 71039                                              NaN         NaN
# 71040      MULTINATIONAL MARITIME MANILA - PHILIPPINES         NaN
#
#       Engine model Engine power Draft
# 0              NaN          NaN   NaN
# 1              NaN          NaN   NaN
# 2              NaN          NaN   NaN
# 3              NaN          NaN   NaN
# 4              NaN          NaN   NaN
# ...            ...          ...   ...
# 71036       6S60MC      9480 KW   NaN
# 71037          NaN          NaN   NaN
# 71038          NaN          NaN   NaN
# 71039          NaN          NaN   NaN
# 71040          NaN          NaN   NaN
#
# [71041 rows x 23 columns]
